# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
read=pd.read_csv("C:/Users/laasy/Desktop/datasets/JNTU Sample data.csv")
data=pd.DataFrame(read)
data
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
data.describe()
# Out:
#              pincode   Loan nature  Existing Loan amount            AGE  \
# count   13435.000000  13435.000000           13435.000000  13435.000000
# mean   514413.112467      1.004838          119970.319762     33.101005
# std      8956.411939      0.069391           63417.170414      8.913726
# min    500001.000000      1.000000           10055.000000     18.000000
# 25%    506313.000000      1.000000           64990.000000     25.000000
# 50%    515832.000000      1.000000          120668.000000     33.000000
# 75%    521402.000000      1.000000          174660.500000     41.000000
# max    534475.000000      2.000000          229988.000000     48.000000
#
#        ADHAAR NUMBER
# count   1.343500e+04
# mean    5.563284e+15
# std     2.487175e+15
# min     1.250000e+15
# 25%     3.420000e+15
# 50%     5.550000e+15
# 75%     7.710000e+15
# max     9.870000e+15

# %%
data.shape
# Out:
# (13435, 20)

# %%
data.apply(lambda x:sum(x.isnull()))
# Out:
# State                          0
# Division                       0
# Region                         0
# Branch                         1
# Route Code                     0
# Village Name                   0
# pincode                        0
# Center Name                    0
# Group Name                     0
# Name                           0
# Loan nature                    0
# Employee Name for clinet       0
# Existing Loan amount           0
# Loan Date                      0
# AGE                            0
# ID_DETAILS                     0
# ADHAAR NUMBER                  0
# Marital_Status                 0
# INCOME SOURCE               3435
# LoanStatus                  4941
# dtype: int64

# %%
data['INCOME SOURCE'].isna().sum()
# Out:
# 3435

# %%
data.dtypes
# Out:
# State                        object
# Division                     object
# Region                       object
# Branch                       object
# Route Code                   object
# Village Name                 object
# pincode                       int64
# Center Name                  object
# Group Name                   object
# Name                         object
# Loan nature                   int64
# Employee Name for clinet     object
# Existing Loan amount          int64
# Loan Date                    object
# AGE                           int64
# ID_DETAILS                   object
# ADHAAR NUMBER               float64
# Marital_Status               object
# INCOME SOURCE                object
# LoanStatus                   object
# dtype: object

# %%
a=data['INCOME SOURCE'].value_counts()
b=data['LoanStatus'].value_counts()
c=data['Branch'].value_counts()
print(a)
print(b)
c
# Out:
# BUSINESS         3023
# AGRICULTURE      2790
# OTHER            1963
# DAIRY            1016
# FLOWER SELLER    1004
# LAND              204
# Name: INCOME SOURCE, dtype: int64
# YES    5965
# NO     2529
# Name: LoanStatus, dtype: int64
# Doddaballapur           297
# Visharam                271
# Arani                   252
# Walaja                  236
# Gingee                  225
# Arakkonam               218
# Thiruvallur             212
# Kollegal                209
# Murugan                 203
# Madapattu               201
# Aranthangi              193
# Thavarakere             184
# Thirukovilur            182
# Katpadi                 177
# Mandya                  153
# Ramnagar                153
# Vellore                 152
# Ulundurpet              150
# Kamatchi                146
# Krishnagiri             140
# Gangavati               138
# Kolaramma               137
# Mulbagal Rural          136
# Tiruvannamalai          136
# Thirukovilur monthly    132
# ...

# %%
data['INCOME SOURCE'].fillna('BUSINESS',inplace=True)

# %%
data['INCOME SOURCE'].isna().sum()
# Out:
# 0

# %%
data['LoanStatus'].fillna('YES',inplace=True)

# %%
data['Branch'].fillna('Doddaballapur',inplace=True)

# %%
data.apply(lambda x:sum(x.isnull()))
# Out:
# State                       0
# Division                    0
# Region                      0
# Branch                      0
# Route Code                  0
# Village Name                0
# pincode                     0
# Center Name                 0
# Group Name                  0
# Name                        0
# Loan nature                 0
# Employee Name for clinet    0
# Existing Loan amount        0
# Loan Date                   0
# AGE                         0
# ID_DETAILS                  0
# ADHAAR NUMBER               0
# Marital_Status              0
# INCOME SOURCE               0
# LoanStatus                  0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder 
labelencoder=LabelEncoder() 
data['LoanStatus']=labelencoder.fit_transform(data['LoanStatus'])
data['INCOME SOURCE']=labelencoder.fit_transform(data['INCOME SOURCE'])
data['Marital_Status']=labelencoder.fit_transform(data['Marital_Status'])
data
# Out:
#             State Division         Region        Branch Route Code  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur   KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2   KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala   KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma   KKOLKOLB
# ...

# %%
data.boxplot(column='INCOME SOURCE')

# %%
data.columns
# Out:
# Index(['State', 'Division', 'Region', 'Branch', 'Route Code', 'Village Name',
#        'pincode', 'Center Name', 'Group Name', 'Name', 'Loan nature',
#        'Employee Name for clinet', 'Existing Loan amount ', 'Loan Date', 'AGE',
#        'ID_DETAILS', 'ADHAAR NUMBER', 'Marital_Status', 'INCOME SOURCE',
#        'LoanStatus'],
#       dtype='object')

# %%
data.boxplot(column='LoanStatus')

# %%
data.boxplot(column='AGE')

# %%
data.boxplot(column='Existing Loan amount ')

# %%
X=data.iloc[:,[12,14,17,18]].values 
y=data.iloc[:,[19]].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=0)

# %%
X_test
# Out:
# array([[217282,     48,      1,      5],
#        [111423,     40,      1,      3],
#        [ 10712,     22,      2,      1],
#        ...,
#        [ 35890,     25,      1,      1],
#        [ 56671,     35,      1,      1],
#        [116421,     23,      1,      1]], dtype=int64)

# %%
from sklearn.linear_model.logistic import LogisticRegression
lgsr=LogisticRegression(random_state=0)
lgsr.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=lgsr.predict(X_test) 
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import confusion_matrix 
conf_matrix=confusion_matrix(y_pred,y_test)
conf_matrix
# Out:
# array([[   0,    0],
#        [1019, 4355]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score 
acc_sco=accuracy_score(y_test,y_pred) 
acc_sco
# Out:
# 0.810383327130629

# %% [markdown]
# ***Decision Tree****

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc_y_test=dtc_clf.predict(X_test) 
dtc_y_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
dtc_cm_test=confusion_matrix(y_test,dtc_y_test) 
dtc_cm_test
# Out:
# array([[ 229,  790],
#        [ 817, 3538]], dtype=int64)

# %%
dtc_accu_test=accuracy_score(y_test,dtc_y_test) 
dtc_accu_test
# Out:
# 0.7009676218831411

# %% [markdown]
# ***NAIVE BAYES***

# %%
9from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(X,y)
GaussianNB()
y2_predict=clf.predict(X_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
conf_matrix=confusion_matrix(y2_predict,y_test)
conf_matrix
# Out:
# array([[   0,    0],
#        [1019, 4355]], dtype=int64)

# %%
nvc=accuracy_score(y_test,y2_predict)
nvc
# Out:
# 0.810383327130629

# %% [markdown]
# *****Random Forest*****
